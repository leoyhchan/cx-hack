# %%
import time
import random
import math
import numpy as np
import pandas as pd
from src.model_savers import save_softmax_classifier
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_excel('satisfaction.xlsx')

# faster than encoding
df_2 = pd.get_dummies(df,drop_first=True)

X = df_2.iloc[:, range(1,9)].values
y = df_2.iloc[:, 0].values


# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the data set;
# we can use this for development so our code runs faster.
num_training = 48000
num_validation = 1000
num_test = 1000
num_dev = 500

assert (num_training + num_validation + num_test) == 50000, 'You have not provided a valid data split.'

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X[mask]
y_train = y[mask]

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X[mask]
y_val = y[mask]

# We use a small subset of the training set as our test set.
mask = range(num_training + num_validation, num_training + num_validation + num_test)
X_test = X[mask]
y_test = y[mask]

# We will also make a development set, which is a small subset of
# the training set. This way the development cycle is faster.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (48000, 8)
# Validation data shape:  (1000, 8)
# Test data shape:  (1000, 8)
# dev data shape:  (500, 8)

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our classifier
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# (48000, 9) (1000, 9) (1000, 9) (500, 9)

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
from src.classifiers.softmax import SoftmaxClassifier

# The SoftmaxClassifier class inherits from LinearClassifier
softmax = SoftmaxClassifier()
tic = time.time()
loss_hist = softmax.train(X_train, y_train, learning_rate=1e-7, reg=5e4,
                          num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 2.545220
# iteration 100 / 1500: loss 1.949386
# iteration 200 / 1500: loss 1.731938
# iteration 300 / 1500: loss 1.653784
# iteration 400 / 1500: loss 1.627119
# iteration 500 / 1500: loss 1.617930
# iteration 600 / 1500: loss 1.613895
# iteration 700 / 1500: loss 1.609510
# iteration 800 / 1500: loss 1.609406
# iteration 900 / 1500: loss 1.611753
# iteration 1000 / 1500: loss 1.608063
# iteration 1100 / 1500: loss 1.609473
# iteration 1200 / 1500: loss 1.609633
# iteration 1300 / 1500: loss 1.608894
# iteration 1400 / 1500: loss 1.608857
# That took 0.256238s

# %%
# A useful debugging strategy is to plot the loss as a function of iterations:
plt.figure(figsize=(6,5))
plt.plot(loss_hist)
plt.xlabel('Iterations')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# Write the `LinearClassifier.predict` method and evaluate the performance on both the training and validation set:

# %%
y_train_pred = softmax.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = softmax.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.199979
# validation accuracy: 0.209000

# %% [markdown]
# ### Training Softmax Classifier
# Use the validation set to tune hyperparameters (regularization strength and learning rate).

# %%
from src.classifiers.softmax import SoftmaxClassifier, softmax_hyperparameter_tuning

best_softmax, results, all_classifiers = softmax_hyperparameter_tuning(X_train, y_train, X_val, y_val)
# Out:
# ================================================================================================================================================================================================================================================================lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.199458 val accuracy: 0.210000
# lr 1.000000e-08 reg 1.500000e+04 train accuracy: 0.201708 val accuracy: 0.215000
# lr 1.000000e-08 reg 2.000000e+04 train accuracy: 0.199833 val accuracy: 0.189000
# lr 1.000000e-08 reg 2.500000e+04 train accuracy: 0.201125 val accuracy: 0.210000
# lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 1.000000e-08 reg 3.500000e+04 train accuracy: 0.198687 val accuracy: 0.171000
# lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.201292 val accuracy: 0.214000
# lr 1.000000e-08 reg 4.500000e+04 train accuracy: 0.199146 val accuracy: 0.211000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.199917 val accuracy: 0.189000
# lr 1.000000e-08 reg 5.500000e+04 train accuracy: 0.199937 val accuracy: 0.209000
# lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.199813 val accuracy: 0.223000
# lr 1.000000e-08 reg 6.500000e+04 train accuracy: 0.199104 val accuracy: 0.209000
# lr 1.000000e-08 reg 7.000000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 1.000000e-08 reg 7.500000e+04 train accuracy: 0.202729 val accuracy: 0.212000
# lr 1.000000e-08 reg 8.000000e+04 train accuracy: 0.201271 val accuracy: 0.219000
# lr 1.000000e-08 reg 8.500000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 1.500000e-08 reg 1.000000e+04 train accuracy: 0.198729 val accuracy: 0.205000
# lr 1.500000e-08 reg 1.500000e+04 train accuracy: 0.198875 val accuracy: 0.201000
# lr 1.500000e-08 reg 2.000000e+04 train accuracy: 0.202250 val accuracy: 0.192000
# lr 1.500000e-08 reg 2.500000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 1.500000e-08 reg 3.000000e+04 train accuracy: 0.199396 val accuracy: 0.211000
# lr 1.500000e-08 reg 3.500000e+04 train accuracy: 0.202146 val accuracy: 0.209000
# lr 1.500000e-08 reg 4.000000e+04 train accuracy: 0.198813 val accuracy: 0.193000
# lr 1.500000e-08 reg 4.500000e+04 train accuracy: 0.198333 val accuracy: 0.173000
# lr 1.500000e-08 reg 5.000000e+04 train accuracy: 0.198458 val accuracy: 0.177000
# lr 1.500000e-08 reg 5.500000e+04 train accuracy: 0.199792 val accuracy: 0.214000
# lr 1.500000e-08 reg 6.000000e+04 train accuracy: 0.201333 val accuracy: 0.196000
# lr 1.500000e-08 reg 6.500000e+04 train accuracy: 0.197750 val accuracy: 0.201000
# lr 1.500000e-08 reg 7.000000e+04 train accuracy: 0.199854 val accuracy: 0.181000
# lr 1.500000e-08 reg 7.500000e+04 train accuracy: 0.199542 val accuracy: 0.184000
# lr 1.500000e-08 reg 8.000000e+04 train accuracy: 0.203667 val accuracy: 0.207000
# lr 1.500000e-08 reg 8.500000e+04 train accuracy: 0.199708 val accuracy: 0.219000
# lr 2.000000e-08 reg 1.000000e+04 train accuracy: 0.200625 val accuracy: 0.209000
# lr 2.000000e-08 reg 1.500000e+04 train accuracy: 0.201687 val accuracy: 0.198000
# lr 2.000000e-08 reg 2.000000e+04 train accuracy: 0.200792 val accuracy: 0.213000
# lr 2.000000e-08 reg 2.500000e+04 train accuracy: 0.199063 val accuracy: 0.194000
# lr 2.000000e-08 reg 3.000000e+04 train accuracy: 0.200625 val accuracy: 0.195000
# lr 2.000000e-08 reg 3.500000e+04 train accuracy: 0.201187 val accuracy: 0.218000
# lr 2.000000e-08 reg 4.000000e+04 train accuracy: 0.202437 val accuracy: 0.211000
# lr 2.000000e-08 reg 4.500000e+04 train accuracy: 0.199292 val accuracy: 0.199000
# lr 2.000000e-08 reg 5.000000e+04 train accuracy: 0.201687 val accuracy: 0.202000
# lr 2.000000e-08 reg 5.500000e+04 train accuracy: 0.201187 val accuracy: 0.208000
# lr 2.000000e-08 reg 6.000000e+04 train accuracy: 0.202521 val accuracy: 0.209000
# lr 2.000000e-08 reg 6.500000e+04 train accuracy: 0.200208 val accuracy: 0.170000
# lr 2.000000e-08 reg 7.000000e+04 train accuracy: 0.200958 val accuracy: 0.220000
# lr 2.000000e-08 reg 7.500000e+04 train accuracy: 0.202063 val accuracy: 0.210000
# lr 2.000000e-08 reg 8.000000e+04 train accuracy: 0.200021 val accuracy: 0.213000
# lr 2.000000e-08 reg 8.500000e+04 train accuracy: 0.199875 val accuracy: 0.199000
e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 4.500000e-08 reg 5.000000e+04 train accuracy: 0.201521 val accuracy: 0.193000
# lr 4.500000e-08 reg 5.500000e+04 train accuracy: 0.200667 val accuracy: 0.199000
# lr 4.500000e-08 reg 6.000000e+04 train accuracy: 0.201000 val accuracy: 0.188000
# lr 4.500000e-08 reg 6.500000e+04 train accuracy: 0.202000 val accuracy: 0.219000
# lr 4.500000e-08 reg 7.000000e+04 train accuracy: 0.198042 val accuracy: 0.195000
# lr 4.500000e-08 reg 7.500000e+04 train accuracy: 0.202083 val accuracy: 0.216000
# lr 4.500000e-08 reg 8.000000e+04 train accuracy: 0.200000 val accuracy: 0.209000
# lr 4.500000e-08 reg 8.500000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.202563 val accuracy: 0.187000
# lr 5.000000e-08 reg 1.500000e+04 train accuracy: 0.201854 val accuracy: 0.200000
# lr 5.000000e-08 reg 2.000000e+04 train accuracy: 0.202021 val accuracy: 0.196000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 5.000000e-08 reg 3.000000e+04 train accuracy: 0.199625 val accuracy: 0.199000
# lr 5.000000e-08 reg 3.500000e+04 train accuracy: 0.202146 val accuracy: 0.196000
# lr 5.000000e-08 reg 4.000000e+04 train accuracy: 0.202167 val accuracy: 0.216000
# lr 5.000000e-08 reg 4.500000e+04 train accuracy: 0.199896 val accuracy: 0.222000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.200229 val accuracy: 0.185000
# lr 5.000000e-08 reg 5.500000e+04 train accuracy: 0.202583 val accuracy: 0.216000
# lr 5.000000e-08 reg 6.000000e+04 train accuracy: 0.201604 val accuracy: 0.199000
# lr 5.000000e-08 reg 6.500000e+04 train accuracy: 0.200521 val accuracy: 0.218000
# lr 5.000000e-08 reg 7.000000e+04 train accuracy: 0.201250 val accuracy: 0.218000
# lr 5.000000e-08 reg 7.500000e+04 train accuracy: 0.200354 val accuracy: 0.210000
# lr 5.000000e-08 reg 8.000000e+04 train accuracy: 0.201667 val accuracy: 0.196000
# lr 5.000000e-08 reg 8.500000e+04 train accuracy: 0.199563 val accuracy: 0.193000
# lr 5.500000e-08 reg 1.000000e+04 train accuracy: 0.201833 val accuracy: 0.198000
# lr 5.500000e-08 reg 1.500000e+04 train accuracy: 0.200104 val accuracy: 0.193000
# lr 5.500000e-08 reg 2.000000e+04 train accuracy: 0.201313 val accuracy: 0.219000
# lr 5.500000e-08 reg 2.500000e+04 train accuracy: 0.200771 val accuracy: 0.220000
# lr 5.500000e-08 reg 3.000000e+04 train accuracy: 0.198958 val accuracy: 0.200000
# lr 5.500000e-08 reg 3.500000e+04 train accuracy: 0.201458 val accuracy: 0.218000
# lr 5.500000e-08 reg 4.000000e+04 train accuracy: 0.201208 val accuracy: 0.218000
# lr 5.500000e-08 reg 4.500000e+04 train accuracy: 0.199292 val accuracy: 0.196000
# lr 5.500000e-08 reg 5.000000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 5.500000e-08 reg 5.500000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 5.500000e-08 reg 6.000000e+04 train accuracy: 0.202063 val accuracy: 0.208000
# lr 5.500000e-08 reg 6.500000e+04 train accuracy: 0.201250 val accuracy: 0.219000
# lr 5.500000e-08 reg 7.000000e+04 train accuracy: 0.198146 val accuracy: 0.209000
# lr 5.500000e-08 reg 7.500000e+04 train accuracy: 0.200000 val accuracy: 0.208000
# lr 5.500000e-08 reg 8.000000e+04 train accuracy: 0.201146 val accuracy: 0.220000
# lr 5.500000e-08 reg 8.500000e+04 train accuracy: 0.199854 val accuracy: 0.209000
# lr 6.000000e-08 reg 1.000000e+04 train accuracy: 0.200646 val accuracy: 0.206000
# lr 6.000000e-08 reg 1.500000e+04 train accuracy: 0.201458 val accuracy: 0.229000
# lr 6.000000e-08 reg 2.000000e+04 train accuracy: 0.201521 val accuracy: 0.211000
# lr 6.000000e-08 reg 2.500000e+04 train accuracy: 0.200937 val accuracy: 0.188000
# lr 6.000000e-08 reg 3.000000e+04 train accuracy: 0.203229 val accuracy: 0.213000
# lr 6.000000e-08 reg 3.500000e+04 train accuracy: 0.201417 val accuracy: 0.219000
# lr 6.000000e-08 reg 4.000000e+04 train accuracy: 0.200563 val accuracy: 0.208000
# lr 6.000000e-08 reg 4.500000e+04 train accuracy: 0.201333 val accuracy: 0.223000
# lr 6.000000e-08 reg 5.000000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 6.000000e-08 reg 5.500000e+04 train accuracy: 0.199937 val accuracy: 0.215000
# lr 6.000000e-08 reg 6.000000e+04 train accuracy: 0.200833 val accuracy: 0.194000
# lr 6.000000e-08 reg 6.500000e+04 train accuracy: 0.201521 val accuracy: 0.217000
# lr 6.000000e-08 reg 7.000000e+04 train accuracy: 0.201542 val accuracy: 0.215000
# lr 6.000000e-08 reg 7.500000e+04 train accuracy: 0.200896 val accuracy: 0.186000
# lr 6.000000e-08 reg 8.000000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 6.000000e-08 reg 8.500000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 6.500000e-08 reg 1.000000e+04 train accuracy: 0.201667 val accuracy: 0.217000
# lr 6.500000e-08 reg 1.500000e+04 train accuracy: 0.199167 val accuracy: 0.220000
# lr 6.500000e-08 reg 2.000000e+04 train accuracy: 0.201667 val accuracy: 0.199000
# lr 6.500000e-08 reg 2.500000e+04 train accuracy: 0.199146 val accuracy: 0.194000
# lr 6.500000e-08 reg 3.000000e+04 train accuracy: 0.198563 val accuracy: 0.194000
# lr 6.500000e-08 reg 3.500000e+04 train accuracy: 0.200854 val accuracy: 0.188000
# lr 6.500000e-08 reg 4.000000e+04 train accuracy: 0.200958 val accuracy: 0.186000
# lr 6.500000e-08 reg 4.500000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 6.500000e-08 reg 5.000000e+04 train accuracy: 0.202000 val accuracy: 0.204000
# lr 6.500000e-08 reg 5.500000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 6.500000e-08 reg 6.000000e+04 train accuracy: 0.203333 val accuracy: 0.220000
# lr 6.500000e-08 reg 6.500000e+04 train accuracy: 0.200437 val accuracy: 0.186000
# lr 6.500000e-08 reg 7.000000e+04 train accuracy: 0.201063 val accuracy: 0.214000
# lr 6.500000e-08 reg 7.500000e+04 train accuracy: 0.199583 val accuracy: 0.221000
# lr 6.500000e-08 reg 8.000000e+04 train accuracy: 0.200896 val accuracy: 0.183000
# lr 6.500000e-08 reg 8.500000e+04 train accuracy: 0.200958 val accuracy: 0.186000
# lr 7.000000e-08 reg 1.000000e+04 train accuracy: 0.199271 val accuracy: 0.204000
# lr 7.000000e-08 reg 1.500000e+04 train accuracy: 0.200667 val accuracy: 0.193000
# lr 7.000000e-08 reg 2.000000e+04 train accuracy: 0.201583 val accuracy: 0.217000
# lr 7.000000e-08 reg 2.500000e+04 train accuracy: 0.201458 val accuracy: 0.190000
# lr 7.000000e-08 reg 3.000000e+04 train accuracy: 0.199146 val accuracy: 0.209000
# lr 7.000000e-08 reg 3.500000e+04 train accuracy: 0.200729 val accuracy: 0.186000
# lr 7.000000e-08 reg 4.000000e+04 train accuracy: 0.203417 val accuracy: 0.205000
# lr 7.000000e-08 reg 4.500000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 7.000000e-08 reg 5.000000e+04 train accuracy: 0.198375 val accuracy: 0.208000
# lr 7.000000e-08 reg 5.500000e+04 train accuracy: 0.201979 val accuracy: 0.211000
# lr 7.000000e-08 reg 6.000000e+04 train accuracy: 0.199396 val accuracy: 0.191000
# lr 7.000000e-08 reg 6.500000e+04 train accuracy: 0.201250 val accuracy: 0.215000
# lr 7.000000e-08 reg 7.000000e+04 train accuracy: 0.200479 val accuracy: 0.185000
# lr 7.000000e-08 reg 7.500000e+04 train accuracy: 0.202042 val accuracy: 0.216000
# lr 7.000000e-08 reg 8.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 7.000000e-08 reg 8.500000e+04 train accuracy: 0.199625 val accuracy: 0.191000
# lr 7.500000e-08 reg 1.000000e+04 train accuracy: 0.199771 val accuracy: 0.200000
# lr 7.500000e-08 reg 1.500000e+04 train accuracy: 0.201396 val accuracy: 0.190000
# lr 7.500000e-08 reg 2.000000e+04 train accuracy: 0.200937 val accuracy: 0.189000
# lr 7.500000e-08 reg 2.500000e+04 train accuracy: 0.200063 val accuracy: 0.205000
# lr 7.500000e-08 reg 3.000000e+04 train accuracy: 0.202021 val accuracy: 0.208000
# lr 7.500000e-08 reg 3.500000e+04 train accuracy: 0.201604 val accuracy: 0.208000
# lr 7.500000e-08 reg 4.000000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 7.500000e-08 reg 4.500000e+04 train accuracy: 0.200979 val accuracy: 0.186000
# lr 7.500000e-08 reg 5.000000e+04 train accuracy: 0.201333 val accuracy: 0.219000
# lr 7.500000e-08 reg 5.500000e+04 train accuracy: 0.201875 val accuracy: 0.213000
# lr 7.500000e-08 reg 6.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 7.500000e-08 reg 6.500000e+04 train accuracy: 0.200021 val accuracy: 0.209000
# lr 7.500000e-08 reg 7.000000e+04 train accuracy: 0.199167 val accuracy: 0.210000
# lr 7.500000e-08 reg 7.500000e+04 train accuracy: 0.203146 val accuracy: 0.207000
# lr 7.500000e-08 reg 8.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 7.500000e-08 reg 8.500000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 8.000000e-08 reg 1.000000e+04 train accuracy: 0.199458 val accuracy: 0.180000
# lr 8.000000e-08 reg 1.500000e+04 train accuracy: 0.202500 val accuracy: 0.211000
# lr 8.000000e-08 reg 2.000000e+04 train accuracy: 0.202583 val accuracy: 0.219000
# lr 8.000000e-08 reg 2.500000e+04 train accuracy: 0.199500 val accuracy: 0.198000
# lr 8.000000e-08 reg 3.000000e+04 train accuracy: 0.199958 val accuracy: 0.211000
# lr 8.000000e-08 reg 3.500000e+04 train accuracy: 0.201396 val accuracy: 0.218000
# lr 8.000000e-08 reg 4.000000e+04 train accuracy: 0.199979 val accuracy: 0.209000
# lr 8.000000e-08 reg 4.500000e+04 train accuracy: 0.200479 val accuracy: 0.188000
# lr 8.000000e-08 reg 5.000000e+04 train accuracy: 0.199896 val accuracy: 0.209000
# lr 8.000000e-08 reg 5.500000e+04 train accuracy: 0.201667 val accuracy: 0.218000
# lr 8.000000e-08 reg 6.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 8.000000e-08 reg 6.500000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 8.000000e-08 reg 7.000000e+04 train accuracy: 0.200687 val accuracy: 0.187000
# lr 8.000000e-08 reg 7.500000e+04 train accuracy: 0.199750 val accuracy: 0.215000
# lr 8.000000e-08 reg 8.000000e+04 train accuracy: 0.200958 val accuracy: 0.186000
# lr 8.000000e-08 reg 8.500000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 8.500000e-08 reg 1.000000e+04 train accuracy: 0.203250 val accuracy: 0.210000
# lr 8.500000e-08 reg 1.500000e+04 train accuracy: 0.199417 val accuracy: 0.205000
# lr 8.500000e-08 reg 2.000000e+04 train accuracy: 0.198979 val accuracy: 0.203000
# lr 8.500000e-08 reg 2.500000e+04 train accuracy: 0.201271 val accuracy: 0.192000
# lr 8.500000e-08 reg 3.000000e+04 train accuracy: 0.202563 val accuracy: 0.205000
# lr 8.500000e-08 reg 3.500000e+04 train accuracy: 0.201479 val accuracy: 0.197000
# lr 8.500000e-08 reg 4.000000e+04 train accuracy: 0.201292 val accuracy: 0.219000
# lr 8.500000e-08 reg 4.500000e+04 train accuracy: 0.200437 val accuracy: 0.195000
# lr 8.500000e-08 reg 5.000000e+04 train accuracy: 0.201000 val accuracy: 0.186000
# lr 8.500000e-08 reg 5.500000e+04 train accuracy: 0.199813 val accuracy: 0.215000
# lr 8.500000e-08 reg 6.000000e+04 train accuracy: 0.200729 val accuracy: 0.186000
# lr 8.500000e-08 reg 6.500000e+04 train accuracy: 0.201563 val accuracy: 0.217000
# lr 8.500000e-08 reg 7.000000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 8.500000e-08 reg 7.500000e+04 train accuracy: 0.199187 val accuracy: 0.211000
# lr 8.500000e-08 reg 8.000000e+04 train accuracy: 0.201458 val accuracy: 0.218000
# lr 8.500000e-08 reg 8.500000e+04 train accuracy: 0.200979 val accuracy: 0.186000
# best validation accuracy achieved during validation: 0.231000

# %%
# Visualize the validation results
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')

plt.tight_layout()
plt.show()

# %%
# if you want to take a look at the other classifiers assign them to best_softmax here
sorted_classifiers = sorted(all_classifiers, key=lambda x : x[1])
best_softmax = sorted_classifiers[-1][0]

# %%
from src.model_savers import save_softmax_classifier
from src.classifiers.softmax import SoftmaxClassifier

save_softmax_classifier(best_softmax)
